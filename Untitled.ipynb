# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("housing.csv")

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
data.dropna(inplace=True)

# %%
data.info()
data=data.drop('ocean_proximity',axis=1)
data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
# [20433 rows x 9 columns]

# %%
from sklearn.model_selection import train_test_split
x=data.drop(['median_house_value'],axis=1)
y=data['median_house_value']

# %%
x
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income
# 0           322.0       126.0         8.3252
# 1          2401.0      1138.0         8.3014
# 2           496.0       177.0         7.2574
# 3           558.0       219.0         5.6431
# 4           565.0       259.0         3.8462
# ...           ...         ...            ...
# 20635       845.0       330.0         1.5603
# 20636       356.0       114.0         2.5568
# 20637      1007.0       433.0         1.7000
# 20638       741.0       349.0         1.8672
# 20639      1387.0       530.0         2.3886
#
# [20433 rows x 8 columns]

# %%
y
# Out:
# 0        452600.0
# 1        358500.0
# 2        352100.0
# 3        341300.0
# 4        342200.0
#            ...
# 20635     78100.0
# 20636     77100.0
# 20637     92300.0
# 20638     84700.0
# 20639     89400.0
# Name: median_house_value, Length: 20433, dtype: float64

# %%
x_train,x_test,y_train,y_test = train_test_split(x, y, test_size=0.2)

# %%
train_data =x_train.join(y_train)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 3935     -118.57     34.21                23.0       4891.0           793.0
# 15540    -117.14     33.07                12.0       9302.0          1603.0
# 20594    -121.57     39.16                21.0       1872.0           302.0
# 12264    -116.87     33.76                 5.0       4116.0           761.0
# 2121     -119.70     36.75                11.0       3626.0           779.0
# ...          ...       ...                 ...          ...             ...
# 9728     -121.65     36.85                20.0       2606.0           424.0
# 17311    -119.49     34.39                17.0       4617.0           982.0
# 15484    -117.13     33.15                16.0       3907.0           671.0
# 12127    -117.25     33.92                 7.0       9812.0          1914.0
# 8135     -118.13     33.82                44.0       1619.0           280.0
#
#        population  households  median_income  median_house_value
# 3935       2447.0       765.0         5.8798            270500.0
# 15540      4074.0      1504.0         4.3513            199600.0
# 20594       870.0       301.0         3.7250             84700.0
# 12264      1714.0       717.0         2.5612            130800.0
# 2121       1819.0       731.0         2.4956             87500.0
# ...           ...         ...            ...                 ...
# 9728       1361.0       426.0         4.5787            245100.0
# 17311      2303.0       923.0         3.9224            230600.0
# 15484      1759.0       663.0         3.1776            172600.0
# 12127      5595.0      1729.0         4.1482            124600.0
# 8135        815.0       284.0         5.5449            232200.0
#
# [16346 rows x 9 columns]

# %%
train_data.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(),annot = True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
train_data['total_rooms'] = np.log(train_data['total_rooms']+ 1)
train_data['total_bedrooms'] = np.log(train_data['total_bedrooms']+ 1)
train_data['population'] = np.log(train_data['population']+ 1)
train_data['households'] = np.log(train_data['households']+ 1)

# %%
train_data['total_rooms']
# Out:
# 3935     8.495356
# 15540    9.138092
# 20594    7.535297
# 12264    8.322880
# 2121     8.196161
#            ...
# 9728     7.865955
# 17311    8.437717
# 15484    8.270781
# 12127    9.191463
# 8135     7.390181
# Name: total_rooms, Length: 16346, dtype: float64

# %%
train_data['total_bedrooms']
# Out:
# 3935     6.677083
# 15540    7.380256
# 20594    5.713733
# 12264    6.635947
# 2121     6.659294
#            ...
# 9728     6.052089
# 17311    6.890609
# 15484    6.510258
# 12127    7.557473
# 8135     5.638355
# Name: total_bedrooms, Length: 16346, dtype: float64

# %%
train_data['population']
# Out:
# 3935     7.803027
# 15540    8.312626
# 20594    6.769642
# 12264    7.447168
# 2121     7.506592
#            ...
# 9728     7.216709
# 17311    7.742402
# 15484    7.473069
# 12127    8.629807
# 8135     6.704414
# Name: population, Length: 16346, dtype: float64

# %%
train_data['households']
# Out:
# 3935     6.641182
# 15540    7.316548
# 20594    5.710427
# 12264    6.576470
# 2121     6.595781
#            ...
# 9728     6.056784
# 17311    6.828712
# 15484    6.498282
# 12127    7.455877
# 8135     5.652489
# Name: households, Length: 16346, dtype: float64

# %%
train_data.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
#train_data.join(pd.get_dummies(train_data.ocean_proximity)).drop(['ocean_proximity'],axis=1)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 3935     -118.57     34.21                23.0     8.495356        6.677083
# 15540    -117.14     33.07                12.0     9.138092        7.380256
# 20594    -121.57     39.16                21.0     7.535297        5.713733
# 12264    -116.87     33.76                 5.0     8.322880        6.635947
# 2121     -119.70     36.75                11.0     8.196161        6.659294
# ...          ...       ...                 ...          ...             ...
# 9728     -121.65     36.85                20.0     7.865955        6.052089
# 17311    -119.49     34.39                17.0     8.437717        6.890609
# 15484    -117.13     33.15                16.0     8.270781        6.510258
# 12127    -117.25     33.92                 7.0     9.191463        7.557473
# 8135     -118.13     33.82                44.0     7.390181        5.638355
#
#        population  households  median_income  median_house_value
# 3935     7.803027    6.641182         5.8798            270500.0
# 15540    8.312626    7.316548         4.3513            199600.0
# 20594    6.769642    5.710427         3.7250             84700.0
# 12264    7.447168    6.576470         2.5612            130800.0
# 2121     7.506592    6.595781         2.4956             87500.0
# ...           ...         ...            ...                 ...
# 9728     7.216709    6.056784         4.5787            245100.0
# 17311    7.742402    6.828712         3.9224            230600.0
# 15484    7.473069    6.498282         3.1776            172600.0
# 12127    8.629807    7.455877         4.1482            124600.0
# 8135     6.704414    5.652489         5.5449            232200.0
#
# [16346 rows x 9 columns]

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(),annot = True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(x="latitude",y="longitude",data=train_data,hue="median_house_value",palette="coolwarm")
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
train_data['bedroom_ratio']=train_data['total_bedrooms']/train_data['total_rooms']
train_data['household_rooms']=train_data['total_rooms']/train_data['households']

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 3935     -118.57     34.21                23.0     8.495356        6.677083
# 15540    -117.14     33.07                12.0     9.138092        7.380256
# 20594    -121.57     39.16                21.0     7.535297        5.713733
# 12264    -116.87     33.76                 5.0     8.322880        6.635947
# 2121     -119.70     36.75                11.0     8.196161        6.659294
# ...          ...       ...                 ...          ...             ...
# 9728     -121.65     36.85                20.0     7.865955        6.052089
# 17311    -119.49     34.39                17.0     8.437717        6.890609
# 15484    -117.13     33.15                16.0     8.270781        6.510258
# 12127    -117.25     33.92                 7.0     9.191463        7.557473
# 8135     -118.13     33.82                44.0     7.390181        5.638355
#
#        population  households  median_income  median_house_value  \
# 3935     7.803027    6.641182         5.8798            270500.0
# 15540    8.312626    7.316548         4.3513            199600.0
# 20594    6.769642    5.710427         3.7250             84700.0
# 12264    7.447168    6.576470         2.5612            130800.0
# 2121     7.506592    6.595781         2.4956             87500.0
# ...           ...         ...            ...                 ...
# 9728     7.216709    6.056784         4.5787            245100.0
# 17311    7.742402    6.828712         3.9224            230600.0
# 15484    7.473069    6.498282         3.1776            172600.0
# 12127    8.629807    7.455877         4.1482            124600.0
# 8135     6.704414    5.652489         5.5449            232200.0
#
#        bedroom_ratio  household_rooms
# 3935        0.785969         1.279193
# 15540       0.807636         1.248962
# 20594       0.758262         1.319568
# 12264       0.797314         1.265554
# 2121        0.812489         1.242637
# ...              ...              ...
# 9728        0.769403         1.298702
# 17311       0.816644         1.235623
# 15484       0.787139         1.272764
# 12127       0.822227         1.232781
# 8135        0.762952         1.307421
#
# [16346 rows x 11 columns]

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(),annot = True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler

scaler=StandardScaler()

x_train, y_train = train_data.drop(['median_house_value'],axis=1),train_data['median_house_value']
x_train_s=scaler.fit_transform(x_train)

reg=LinearRegression()

reg.fit(x_train_s,y_train)
# Out:
# LinearRegression()

# %%
test_data =x_test.join(y_test)

test_data['total_rooms'] = np.log(test_data['total_rooms']+ 1)
test_data['total_bedrooms'] = np.log(test_data['total_bedrooms']+ 1)
test_data['population'] = np.log(test_data['population']+ 1)
test_data['households'] = np.log(test_data['households']+ 1)

#test_data.join(pd.get_dummies(train_data.ocean_proximity)).drop(['ocean_proximity'],axis=1)

test_data['bedroom_ratio']=test_data['total_bedrooms']/test_data['total_rooms']
test_data['household_rooms']=test_data['total_rooms']/test_data['households']

# %%
test_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1157     -121.47     39.51                19.0     8.221748        6.456770
# 15116    -117.00     32.85                24.0     7.543803        5.768321
# 14129    -117.09     32.75                20.0     7.439559        6.222576
# 14357    -117.21     32.74                52.0     7.127694        5.164786
# 10041    -121.06     39.21                52.0     7.281386        5.736572
# ...          ...       ...                 ...          ...             ...
# 17548    -121.87     37.35                27.0     8.160804        6.944087
# 5217     -118.23     33.95                37.0     7.889084        6.510258
# 16257    -121.25     37.97                34.0     7.161622        5.843544
# 2490     -120.31     36.65                24.0     6.850126        5.347108
# 18755    -122.35     40.68                36.0     7.508239        6.109248
#
#        population  households  median_income  median_house_value  \
# 1157     7.173958    6.410175         2.6921             97500.0
# 15116    6.857514    5.768321         5.2820            140800.0
# 14129    7.301822    6.144186         1.6789             95500.0
# 14357    6.150603    5.267858         6.9322            334500.0
# 10041    6.458338    5.703782         2.2083            103900.0
# ...           ...         ...            ...                 ...
# 17548    8.013012    6.862758         2.9222            153700.0
# 5217     7.960673    6.527958         0.6831             87500.0
# 16257    6.741701    5.683580         1.7895             63100.0
# 2490     6.244167    5.056246         2.2500             76600.0
# 18755    6.836259    5.991465         1.3801             56600.0
#
#        bedroom_ratio  household_rooms
# 1157        0.785328         1.282609
# 15116       0.764644         1.307799
# 14129       0.836417         1.210829
# 14357       0.724608         1.353053
# 10041       0.787841         1.276589
# ...              ...              ...
# 17548       0.850907         1.189143
# 5217        0.825224         1.208507
# 16257       0.815953         1.260055
# 2490        0.780585         1.354785
# 18755       0.813673         1.253156
#
# [4087 rows x 11 columns]

# %%
x_test, y_test = test_data.drop(['median_house_value'],axis=1), test_data['median_house_value']

# %%
x_test_s=scaler.transform(x_test)

# %%
reg.score(x_test,y_test)
# Out:
# C:\Users\Bunny\anaconda3\Lib\site-packages\sklearn\base.py:457: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(
# -4021.185451972199

# %%
from sklearn.ensemble import RandomForestRegressor

forest = RandomForestRegressor()

forest.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
forest.score(x_test_s,y_test)
# Out:
# C:\Users\Bunny\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# -0.2114317088177382

# %%
from sklearn.model_selection import GridSearchCV
forest =RandomForestRegressor()

param_grid ={ #hyperparametrs
    "n_estimators": [30,50,100],
   
    "max_depth":[None,4,8]
}
grid_search =GridSearchCV(forest, param_grid, cv=5,scoring="neg_mean_squared_error",return_train_score=True) #cross validation
grid_search.fit(x_train_s,y_train)

# %%
best_forest =grid_search.best_estimator_

# %%
best_forest.score(x_test_s,y_test)
